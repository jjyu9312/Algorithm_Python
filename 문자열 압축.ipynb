# %%
''' https://programmers.co.kr/learn/courses/30/lessons/60057 '''
# Out:
# ' https://programmers.co.kr/learn/courses/30/lessons/60057 '

# %%
'''
"aabbaccc"	7
"ababcdcdababcdcd"	9
"abcabcdede"	8
"abcabcabcabcdededededede"	14
"xababcdcdababcdcd"	17
'''

# %%
s = "aabbaccc"

# %%
s.count('a')
# Out:
# 3

# %%
# 1
# 파이썬
def solution(s):
    LENGTH = len(s)
    cand = [LENGTH]  # 1~len까지 압축했을때 길이 값

    for size in range(1, LENGTH):
        compressed = ""
        # string 갯수 단위로 쪼개기 *
        splited = [s[i:i+size] for i in range(0, LENGTH, size)]
        count = 1

        for j in range(1, len(splited)):
            prev, cur = splited[j-1], splited[j]
            if prev == cur:  # 이전 문자와 동일하다면
                count += 1
            else:  # 이전 문자와 다르다면
                compressed += (str(count) + prev) if count > 1 else prev
                count = 1  # 초기화

        compressed += (str(count) + splited[-1]) if count > 1 else splited[-1]
        cand.append(len(compressed))

    return min(cand)  # 최솟값 리턴


# 2
def solution2(s):
    LENGTH = len(s)
    STR, COUNT = 0, 1
    cand = [LENGTH]  # 1~len까지 압축했을때 길이 값

    for size in range(1, LENGTH):
        compressed = ""
        # string 갯수 단위로 쪼개기 *
        splited = [s[i:i+size] for i in range(0, LENGTH, size)]
        stack = [[splited[0], 1]]

        for unit in splited[1:]:
            if stack[-1][STR] != unit:  # 이전 문자와 다르다면
                stack.append([unit, 1])
            else:  # 이전 문자와 다르다면
                stack[-1][COUNT] += 1

        compressed += ('').join([str(cnt) + w if cnt > 1 else w for w, cnt in stack])
        cand.append(len(compressed))

    return min(cand)  # 최솟값 리턴

# %%
s = "aabbaccc"
length = len(s)
c = [length]

# %%
for size in range(1, length):
    compressed = ""
    splited = [s[i:i+size] for i in range(0, length, size)]
    print(f'splited : {splited}')
    count = 1
    for j in range(1, len(splited)):
        prev, cur = splited[j-1], splited[j]
        print(f'prev : {prev}')
        print(f'cur : {cur}')
        if prev == cur:
            count += 1
        else:
            compressed += (str(count) + prev) if count > 1 else prev
            count = 1
            print(f'compressed_1 : {compressed}')

        print(f'splited[-1] : {splited[-1]}')
        compressed += (str(count) + splited[-1]) if count > 1 else splited[-1]
        print(f'compressed_2 : {compressed}')
    
    print(f'len : {len(compressed)}')
    print()

# %%
def solution(s):
    LENGTH = len(s)
    cand = [LENGTH]  # 1~len까지 압축했을때 길이 값

    for size in range(1, LENGTH):
        compressed = ""
        # string 갯수 단위로 쪼개기 *
        splited = [s[i:i+size] for i in range(0, LENGTH, size)]
        print(f'splited : {splited}')
        count = 1

        for j in range(1, len(splited)):
            prev, cur = splited[j-1], splited[j]
            print(f'prev : {prev}')
            print(f'cur : {cur}')
            if prev == cur:  # 이전 문자와 동일하다면
                count += 1
            else:  # 이전 문자와 다르다면
                compressed += (str(count) + prev) if count > 1 else prev
                count = 1  # 초기화
                print(f'compressed_1 : {compressed}')

            print(f'splited[-1] : {splited[-1]}')

        compressed += (str(count) + splited[-1]) if count > 1 else splited[-1]
        print(f'compressed_2 : {compressed}')
    
    print(f'len : {len(compressed)}')
    print()
        
    cand.append(len(compressed))

    return cand  # 최솟값 리턴
