# %%
def solution(number, k):
    answer = ''
    
    
    return answer

# %%
number = "1924"
k = 2

# %%
stack = []

# %%
for i in number:
    while stack and i > stack[-1]:
        if k > 0:
            stack.pop()
            k -= 1
        else:
            break
    stack.append(i)

if k > 0:
    for i in range(k):
        stack.pop()

answer = "".join(stack)
# Out:
# ['1']
